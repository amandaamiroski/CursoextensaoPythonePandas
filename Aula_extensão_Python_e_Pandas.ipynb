# %% [markdown]
# <a href="https://colab.research.google.com/github/amandaamiroski/CursoextensaoPythonePandas/blob/main/Aula_extens%C3%A3o_Python_e_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# ## **Aula 02 - Terça (07/02/2023)**
#
# ---

# %%
import pandas as pd
combustiveis_df = pd.read_excel("ca-2021-02.xlsx")

# %%
print(combustiveis_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
#Para fazer com que sejam exibidas as 5 primeiras linhas
display(combustiveis_df.head())
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# ...

# %%
#Para fazer que seja exibida x linhas
display(combustiveis_df.head(15))
# Out:
#    Regiao - Sigla Estado - Sigla        Municipio  \
# 0              NE             AL        ARAPIRACA
# 1              NE             AL        ARAPIRACA
# 2              NE             AL        ARAPIRACA
# 3              NE             AL        ARAPIRACA
# 4              NE             AL        ARAPIRACA
# 5              NE             AL  DELMIRO GOUVEIA
# 6              NE             AL  DELMIRO GOUVEIA
# 7              NE             AL  DELMIRO GOUVEIA
# 8              NE             AL  DELMIRO GOUVEIA
# 9              NE             AL  DELMIRO GOUVEIA
# 10             NE             AL  DELMIRO GOUVEIA
# 11             NE             AL  DELMIRO GOUVEIA
# 12             NE             AL  DELMIRO GOUVEIA
# 13             NE             AL  DELMIRO GOUVEIA
# 14             NE             AL  DELMIRO GOUVEIA
#
#                                   Revenda      CNPJ da Revenda  \
# 0                    POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
#Para que mostre somente o número de linhas e colunas
print(combustiveis_df.shape)
# Out:
# (168409, 16)

# %%
#Para mostrar os dados estatísticos básicos
print(combustiveis_df.describe())
# Out:
#        Valor de Venda  Valor de Compra
# count   168409.000000              0.0
# mean         6.005184              NaN
# std          0.794541              NaN
# min          2.849000              NaN
# 25%          5.339000              NaN
# 50%          5.859000              NaN
# 75%          6.699000              NaN
# max          8.990000              NaN

# %%
#Para filtrar uma coluna
display(combustiveis_df['Revenda'])
# Out:
# 0                               POSTO ARAPIRACA LTDA
# 1                               POSTO ARAPIRACA LTDA
# 2                               POSTO ARAPIRACA LTDA
# 3                               POSTO ARAPIRACA LTDA
# 4                               POSTO ARAPIRACA LTDA
#                              ...
# 168404    COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
# 168405             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168406             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168407             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168408             ABC DISTRIBUICAO DE PETROLEO LTDA
# Name: Revenda, Length: 168409, dtype: object

# %%
#Para filtrar mais de uma coluna
ca_df = combustiveis_df[['Revenda', 'Municipio', 'Produto', 'Valor de Venda']]
display(ca_df)
# Out:
#                                            Revenda  Municipio  \
# 0                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 1                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 2                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 3                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 4                             POSTO ARAPIRACA LTDA  ARAPIRACA
# ...                                            ...        ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA     JEQUIE
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
#
#                    Produto  Valor de Venda
# 0                 GASOLINA           6.799
# 1                   ETANOL           5.299
# 2                   DIESEL           5.549
# 3       GASOLINA ADITIVADA           6.899
# ...

# %%
#Para exibir somente linha x
display(ca_df.loc[3])
# Out:
# Revenda           POSTO ARAPIRACA LTDA
# Municipio                    ARAPIRACA
# Produto             GASOLINA ADITIVADA
# Valor de Venda                   6.899
# Name: 3, dtype: object

# %%
#Para exibir somente da linha x até a y
display(ca_df[9:19])
# Out:
#                                   Revenda        Municipio  \
# 9          AUTO POSTO FREITAS & MAIA LTDA  DELMIRO GOUVEIA
# 10               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 11               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 12               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 13               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 14  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 15  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 16  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 17  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 18  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
#
#                Produto  Valor de Venda
# 9           DIESEL S10           5.983
# 10            GASOLINA           7.197
# 11              ETANOL           5.987
# 12              DIESEL           5.978
# 13          DIESEL S10           5.989
# 14            GASOLINA           7.175
# ...

# %%
#Para criar um df que tenha somente 4 colunas (revenda, municipio, produto e valor de venda) sobre a gasolina
gas_df = ca_df.loc[ca_df['Produto'] == 'GASOLINA']
display(gas_df)
# Out:
#                                                   Revenda  \
# 0                                    POSTO ARAPIRACA LTDA
# 5                          AUTO POSTO FREITAS & MAIA LTDA
# 10                               AUTO POSTO DA PEDRA LTDA
# 14                  COMERCIO DE COMBUSTIVEIS NENZITA LTDA
# 19                         MARCOS ANTONIO DA SILVA CABRAL
# ...                                                   ...
# 168392                           AUTO POSTO KM BAURU LTDA
# 168394      COOPERCITRUS COOPERATIVA DE PRODUTORES RURAIS
# 168399  VICMAR COMERCIO DE COMBUSTIVEIS E LUBRIFICANTE...
# 168403         COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
# 168405                  ABC DISTRIBUICAO DE PETROLEO LTDA
#
#                     Municipio   Produto  Valor de Venda
# 0                   ARAPIRACA  GASOLINA           6.799
# 5             DELMIRO GOUVEIA  GASOLINA           7.198
# 10            DELMIRO GOUVEIA  GASOLINA           7.197
# ...

# %%
#Para mostrar o valor mais alto de venda
display(gas_df['Valor de Venda'].max())
# Out:
# 7.999

# %%
#Para mostrar qual é o porto e municipio com a gasolina mais cara
display(gas_df[['Revenda', 'Municipio', 'Valor de Venda']].max())
# Out:
# Revenda           ZV POSTO DE SERVIÇO LTDA.
# Municipio                           XANXERE
# Valor de Venda                        7.999
# dtype: object

# %% [markdown]
# ## **Aula 03 - Quarta (08/02/2023)**
#
# ---

# %%
print ("Hello world!")
# Out:
# Hello world!

# %%
#Utilizando o dataframe.loc[] com multiplas condições para filtrar
#Ex: postos que vendem etanol em indaiatuba e o preço
#.sort_values serve para mudar a ordem dos valores,
#e o ascending=True é para que seja ordenado de maneira crescente
#ascending=False é para que seja de maneira decrescente

etanol_indaiatuba_df = ca_df.loc[(ca_df['Produto'] == 'ETANOL') & (ca_df['Municipio'] == 'INDAIATUBA')]
etanol_indaiatuba_df.sort_values(by='Valor de Venda', inplace=True, ascending=True)
display(etanol_indaiatuba_df)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                                         Revenda   Municipio Produto  \
# 160592             AUTO POSTO NAMORADA II LTDA.  INDAIATUBA  ETANOL
# 140194  CENTRO AUTOMOTIVO RIVIERA TROPICAL LTDA  INDAIATUBA  ETANOL
# 140661      M.LI COMERCIO DE COMBUSTIVEIS LTDA.  INDAIATUBA  ETANOL
# 159497      M.LI COMERCIO DE COMBUSTIVEIS LTDA.  INDAIATUBA  ETANOL
# 141167      AUTO POSTO ESPLANADA DE INDAIA LTDA  INDAIATUBA  ETANOL
# ...                                         ...         ...     ...
# 51129          AUTO POSTO CIDADE DO SOL II LTDA  INDAIATUBA  ETANOL
# 51138              AUTO POSTO NAMORADA II LTDA.  INDAIATUBA  ETANOL
# ...

# %%
#Qual a média de preços dos combustiveis GASOLINA e GASOLINA ADITIVADA do bairro MOOCA, SP?

display(combustiveis_df.loc[(combustiveis_df['Bairro'] == 'MOOCA') & (combustiveis_df['Municipio'] == 'SAO PAULO') &
                            ((combustiveis_df['Produto'] == 'GASOLINA') | (combustiveis_df['Produto'] =='GASOLINA ADITIVADA')), ['Valor de Venda']]. mean())
#Tem que fazer o .loc de cada coluna necessária (Bairro, Minicipio, Produto e Valor de venda)
#Só pode quebrar o código por causa do &
#.mean() foi só para calcular a média
# Out:
# Valor de Venda    6.575596
# dtype: float64

# %%
#Da para tentar simplificar um pouco usando o insin

display(combustiveis_df.loc[(combustiveis_df['Bairro'] == 'MOOCA') & 
                            (combustiveis_df['Municipio'] == 'SAO PAULO') & 
                            (combustiveis_df['Produto'].isin(["GASOLINA", "GASOLINA ADITIVADA"])), 
                            ['Valor de Venda']].mean())
# Out:
# Valor de Venda    6.575596
# dtype: float64

# %%
# Como mostrar média de valor de venda por combustível de todo o Brasil?
#Como não esta filtrando nada (principalmente linha), somente mostrando uma única coluna não é necessário uso do loc.

media_por_combustivel_df =(ca_df[['Produto', 'Valor de Venda']]).groupby(by='Produto').mean()
display(media_por_combustivel_df)
# Out:
#                     Valor de Venda
# Produto
# DIESEL                    5.375682
# DIESEL S10                5.454901
# ETANOL                    5.456115
# GASOLINA                  6.708741
# GASOLINA ADITIVADA        6.860422
# GNV                       4.392935

# %%
#Para poder inserir novas informações no df
#Quero adicionar uma coluna de valor booleano no combustiveis_df chamada "Ativa" que, por padrão, vai ser true para todas as linhas

combustiveis_df['Ativo'] = True
print(combustiveis_df.info())
display(combustiveis_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168409 entries, 0 to 168408
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     168409 non-null  object
#  1   Estado - Sigla     168409 non-null  object
#  2   Municipio          168409 non-null  object
#  3   Revenda            168409 non-null  object
#  4   CNPJ da Revenda    168409 non-null  object
#  5   Nome da Rua        168409 non-null  object
#  6   Numero Rua         168353 non-null  object
#  7   Complemento        35057 non-null   object
#  8   Bairro             168043 non-null  object
#  9   Cep                168409 non-null  object
#  10  Produto            168409 non-null  object
#  11  Data da Coleta     168409 non-null  datetime64[ns]
#  12  Valor de Venda     168409 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  168409 non-null  object
# ...

# %%
# Para adicionar uma coluna nova chamada "Obs" que preenche automaticamente "TAINHA" quando for o municipio de Florianópolis, SC

#floripa_df = combustiveis_df['Obs'] = np.where(combustiveis_df['Municipio'] == 'FLORIANOPOLIS', 'Tainha', '')
floripa_df = combustiveis_df['Obs'] = ["Tainha" if municipio == 'FLORIANOPOLIS' else '' for municipio in combustiveis_df['Municipio']]
display(floripa_df)  #NÃO APARECE NADA
#Resolver na aula amanhã
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
# Para poder salvar como arquivo excel
etanol_indaiatuba_df.to_excel('etanol_indaiatuba.xlsx', sheet_name='Etanol em Indaiatuba')

#Para tirar o indíce, tem que adicionar no código index=False

# %% [markdown]
# ## **Aula 04 - Quinta (09/02/2023)**
#
#
#
#
# ---

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
combustiveis_df = pd.read_excel("ca-2021-02.xlsx")
display(combustiveis_df.head())
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# ...

# %%
combustiveis_df['Ativo'] = True

display(combustiveis_df.head())
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# ...

# %%
combustiveis_df['Obs'] = ["MELHOR CIDADE" if municipio == 'SAO PAULO' else None for municipio in combustiveis_df['Municipio']]
display(combustiveis_df.loc[combustiveis_df['Municipio'].isin(['SAO PAULO','INDAIATUBA', 'CAMPINAS', 'SALTO']), ['Municipio', 'Obs']])
# Out:
#         Municipio            Obs
# 1601    SAO PAULO  MELHOR CIDADE
# 1602    SAO PAULO  MELHOR CIDADE
# 1603    SAO PAULO  MELHOR CIDADE
# 1604    SAO PAULO  MELHOR CIDADE
# 2607     CAMPINAS           None
# ...           ...            ...
# 165925  SAO PAULO  MELHOR CIDADE
# 165926  SAO PAULO  MELHOR CIDADE
# 166122  SAO PAULO  MELHOR CIDADE
# 166123  SAO PAULO  MELHOR CIDADE
# 166124  SAO PAULO  MELHOR CIDADE
#
# [7742 rows x 2 columns]

# %%
# como preencher uma coluna 'Status do Valor de Venda' que verifica que se o valor de venda for maior que 6,5 reais,
# ele fala que tá Caro..caso contrário, está barato
import numpy as np

combustiveis_df['Status do Valor de Venda'] = np.where(combustiveis_df['Valor de Venda'] > 6.5, 'Caro', 'Barato')
display(combustiveis_df[['Revenda', 'Valor de Venda', 'Status do Valor de Venda']])
# Out:
#                                            Revenda  Valor de Venda  \
# 0                             POSTO ARAPIRACA LTDA           6.799
# 1                             POSTO ARAPIRACA LTDA           5.299
# 2                             POSTO ARAPIRACA LTDA           5.549
# 3                             POSTO ARAPIRACA LTDA           6.899
# 4                             POSTO ARAPIRACA LTDA           5.649
# ...                                            ...             ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA           5.859
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA           6.580
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA           4.740
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA           5.448
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA           6.580
#
#        Status do Valor de Venda
# 0                          Caro
# 1                        Barato
# 2                        Barato
# ...

# %%
#Calcular postos de gasolina por habitantes que temos na amostragem de combustíveis de nov/2021
num_habitantes_df = pd.read_csv("ibge_num_habitantes_estimado.csv", sep=";")
num_habitantes_df.rename(columns={"Estado":"Estado - Sigla"}, inplace=True)
display(num_habitantes_df)
# Out:
#          Municipio Estado - Sigla  NumHabitantes2021
# 0   BELO HORIZONTE             MG            2530701
# 1         CAMPINAS             SP            1223237
# 2     CAMPO GRANDE             MS             916001
# 3         CURITIBA             PR            1963726
# 4          GOIANIA             GO            1555626
# 5       INDAIATUBA             SP             260690
# 6            NATAL             RN             803739
# 7           PALMAS             TO             313349
# 8        PENAPOLIS             SP              64098
# 9     PORTO ALEGRE             RS            1492530
# 10     PORTO VELHO             RO             548952
# 11      RIO BRANCO             AC             419452
# 12  RIO DE JANEIRO             RJ            6775561
# 13    SALTO GRANDE             SP               9396
# 14          SANTOS             SP             433991
# 15       SAO PAULO             SP           12396372
# 16     SAO VICENTE             SP             370839
# ...

# %%
#Para fazer um merge dos dados
#Onde o inner achar correspondencia ele realiza o merge, se não ele ignora e não adiciona a linha
colunas = ['Municipio', 'Estado - Sigla' ]
merge_df = combustiveis_df.merge(num_habitantes_df, how="inner", on=colunas)
display(merge_df)
print(merge_df.info())
# Out:
#       Regiao - Sigla Estado - Sigla   Municipio  \
# 0                 CO             GO     GOIANIA
# 1                 CO             GO     GOIANIA
# 2                 CO             GO     GOIANIA
# 3                 CO             GO     GOIANIA
# 4                 CO             GO     GOIANIA
# ...              ...            ...         ...
# 20629             SE             SP  INDAIATUBA
# 20630             SE             SP  INDAIATUBA
# 20631             SE             SP  INDAIATUBA
# 20632             SE             SP  INDAIATUBA
# 20633             SE             SP  INDAIATUBA
#
#                                          Revenda      CNPJ da Revenda  \
# 0                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 1                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 2                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 3                              POSTO DO BOI LTDA   06.880.293/0001-25
# ...

# %%
#.drop serve para destruir a linha ou coluna que deseja. 
#.dropna destroi a coluna que tem todos os valores nulos
#axis é para determinar linhas ou colunas, 1-colunas
merge_df.dropna(axis=1, inplace=True)
print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Regiao - Sigla            20634 non-null  object
#  1   Estado - Sigla            20634 non-null  object
#  2   Municipio                 20634 non-null  object
#  3   Revenda                   20634 non-null  object
#  4   CNPJ da Revenda           20634 non-null  object
#  5   Nome da Rua               20634 non-null  object
#  6   Numero Rua                20634 non-null  object
#  7   Bairro                    20634 non-null  object
#  8   Cep                       20634 non-null  object
#  9   Produto                   20634 non-null  object
#  10  Data da Coleta            20634 non-null  datetime64[ns]
#  11  Valor de Venda            20634 non-null  float64
#  12  Unidade de Medida         20634 non-null  object
# ...

# %%
colunas=['Regiao - Sigla', 'Nome da Rua', 'Numero Rua', 'Bairro', 'Cep', 'Produto',
         'Data da Coleta', 'Valor de Venda', 'Unidade de Medida', 'Bandeira', 'Ativo', 'Status do Valor de Venda']
merge_df.drop(labels=colunas, axis=1, inplace=True)
print(merge_df.info())

#o inplace=True serve para salvar como o novo df. Serve como se fosse uma atualização do df utilizado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Estado - Sigla     20634 non-null  object
#  1   Municipio          20634 non-null  object
#  2   Revenda            20634 non-null  object
#  3   CNPJ da Revenda    20634 non-null  object
#  4   NumHabitantes2021  20634 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 967.2+ KB
# None

# %%
display(merge_df.head(100))
# Out:
#    Estado - Sigla Municipio                       Revenda  \
# 0              GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 1              GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 2              GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 3              GO   GOIANIA             POSTO DO BOI LTDA
# 4              GO   GOIANIA             POSTO DO BOI LTDA
# ..            ...       ...                           ...
# 95             GO   GOIANIA   AUTO POSTO DONA SANTA LTDA.
# 96             GO   GOIANIA   AUTO POSTO DONA SANTA LTDA.
# 97             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
# 98             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
# 99             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
#
#         CNPJ da Revenda  NumHabitantes2021
# 0    37.831.484/0001-20            1555626
# 1    37.831.484/0001-20            1555626
# 2    37.831.484/0001-20            1555626
# 3    06.880.293/0001-25            1555626
# 4    06.880.293/0001-25            1555626
# ...

# %%
#Para remover as linhas duplicadas
merge_df.drop_duplicates(inplace=True)
display(merge_df.head(100))
# Out:
#      Estado - Sigla       Municipio                                   Revenda  \
# 0                GO         GOIANIA                 AERO SETE AUTO POSTO LTDA
# 3                GO         GOIANIA                         POSTO DO BOI LTDA
# 7                GO         GOIANIA                             POSTO DN LTDA
# 11               GO         GOIANIA                         POSTO ALDEIA LTDA
# 15               GO         GOIANIA               AUTO POSTO SANTA LUZIA LTDA
# ...             ...             ...                                       ...
# 1677             RJ  RIO DE JANEIRO       POSTO SANTA CLARA DA PAVUNA II LTDA
# 1682             RJ  RIO DE JANEIRO          POSTO SANTA CLARA DA PAVUNA LTDA
# 1688             RJ  RIO DE JANEIRO            NOVA PARADINHA AUTO POSTO LTDA
# 1694             RJ  RIO DE JANEIRO            AUTO POSTO LUAR DA PENHA LTDA.
# 1699             RJ  RIO DE JANEIRO  AUTO POSTO FUTURO GNV DE BONSUCESSO LTDA
#
# ...

# %%
#Agrupar e contar quantos postos tem na cidade

postos_por_municipio_df = merge_df.groupby(by=['Estado - Sigla', 'Municipio', 'NumHabitantes2021']).count()
postos_por_municipio_df.reset_index(inplace=True)
postos_por_municipio_df.drop('CNPJ da Revenda', axis=1, inplace=True)
postos_por_municipio_df.rename(columns={"Revenda": "Número de Postos"}, inplace=True)
display(postos_por_municipio_df)

#.groupby serviu para agrupar as informações repetidas
#.count foi para contar o número de linhas
#.rename serviu para arrumar o nome das colunas
#reset.index faz com que o indice seja resertado para o indice padrão - era o motivo do pq o código numhab/numpostos estava dando erro
# Out:
#    Estado - Sigla       Municipio  NumHabitantes2021  Número de Postos
# 0              AC      RIO BRANCO             419452                44
# 1              GO         GOIANIA            1555626                93
# 2              MG  BELO HORIZONTE            2530701                54
# 3              MS    CAMPO GRANDE             916001               104
# 4              PR        CURITIBA            1963726               110
# 5              RJ  RIO DE JANEIRO            6775561               379
# 6              RN           NATAL             803739                37
# 7              RO     PORTO VELHO             548952                40
# 8              RS    PORTO ALEGRE            1492530                73
# 9              SP        CAMPINAS            1223237                51
# 10             SP      INDAIATUBA             260690                36
# 11             SP          SANTOS             433991                36
# ...

# %%
#merge_df.rename(columns={"Número de Postos" = "Num Postos"}, inplace=True)
postos_por_municipio_df['NumHabitantesPorPostos'] =  postos_por_municipio_df['NumHabitantes2021'] / postos_por_municipio_df['Número de Postos']
display(postos_por_municipio_df)


### NÃO DEU CERTO ---- DEU SIIIM, uhu
# Out:
#    Estado - Sigla       Municipio  NumHabitantes2021  Número de Postos  \
# 0              AC      RIO BRANCO             419452                44
# 1              GO         GOIANIA            1555626                93
# 2              MG  BELO HORIZONTE            2530701                54
# 3              MS    CAMPO GRANDE             916001               104
# 4              PR        CURITIBA            1963726               110
# 5              RJ  RIO DE JANEIRO            6775561               379
# 6              RN           NATAL             803739                37
# 7              RO     PORTO VELHO             548952                40
# 8              RS    PORTO ALEGRE            1492530                73
# 9              SP        CAMPINAS            1223237                51
# 10             SP      INDAIATUBA             260690                36
# 11             SP          SANTOS             433991                36
# ...

# %% [markdown]
# ## **Aula 05 - Sexta (10/02/2023)**
#
#
#
#
# ---

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
#Para poder começar a criar gráficos é necessário ter esta biblioteca matplotlib 
#o .pyplot é uma parte de dentro da biblioteca, ou seja, não foi baixada a biblioteca inteira
import matplotlib.pyplot as plt

plt.hist(combustiveis_df['Valor de Venda'], color='purple')
plt.title("Preço dos combustíveis em nov/2021")
plt.xlabel("Preço (em reais)")
plt.ylabel("Quantidade de Coletas")

#Para traçar uma linha com o preço médio
plt.axvline(combustiveis_df['Valor de Venda'].mean(), color='red', linestyle=':', linewidth=1)
# linewidth serve para determinar o tamanho da linha
#Para plotar o gráfico, .show é para mostrar o gráfico, algo que no colab não muda muito mas que se fizer em outro lugar muda muito.
plt.show()

# %%
c_mean = combustiveis_df['Valor de Venda'].groupby(by=combustiveis_df['Produto']).mean()
display(c_mean)
# Out:
# Produto
# DIESEL                5.375682
# DIESEL S10            5.454901
# ETANOL                5.456115
# GASOLINA              6.708741
# GASOLINA ADITIVADA    6.860422
# GNV                   4.392935
# Name: Valor de Venda, dtype: float64

# %%
import seaborn as sns
#para poder definir a área do gráfico
#Para fazer as caracteristicas do gráfico
plt.figure(figsize=(10,5))
c_mean.plot(kind="bar", xlabel="Tipo de combustível", ylabel="Preço reais/litro", title="Média de preços por combustível",
            alpha=0.3, color="orange" )

#para fazer o grid
plt.grid(axis="x")
#Para tirar as bordas do gráfico
sns.despine()

plt.show()

# %%
#Para trabalhar com excel
from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Font, Color, Alignment

# %%
#c_mean.reset_index(inplace=True)
#display(c_mean)

excel="por litro.xlsx"
c_mean.to_excel(excel, "Sumário")
display(c_mean)
# Out:
# Produto
# DIESEL                5.375682
# DIESEL S10            5.454901
# ETANOL                5.456115
# GASOLINA              6.708741
# GASOLINA ADITIVADA    6.860422
# GNV                   4.392935
# Name: Valor de Venda, dtype: float64

# %%
#Para personalizar a planilha Excel
from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Font, Color, Alignment
#para abrir o excel no openpyxl
wb = load_workbook(excel)

ws = wb['Sumário']

#Para pintar o cabeçalho da tabela
cinzinha = PatternFill("solid", fgColor="909090")
coords =['A1', 'B1']
for coord in coords: 
 ws[coord].fill = cinzinha

 #Onde o preço do combustível for maior ou igual a 6,5 reais, é para pintar de vermelho e deixar em negrito
 MAX_ROW = ws.max_row
num_linha = 2
while(num_linha <= MAX_ROW):
  coord = 'B' + str(num_linha)
  if ws[coord].value >= 6.5:
    ws[coord].font = Font(bold=True, color="FF0000")
  num_linha = num_linha + 1

 #Para salvar o excel
wb.save(excel)
